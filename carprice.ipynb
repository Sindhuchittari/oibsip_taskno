# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('CarPrice.csv')
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
x=data.iloc[:,:-1].values

# %%
x
# Out:
# array([[1, 3, 'alfa-romero giulia', ..., 5000, 21, 27],
#        [2, 3, 'alfa-romero stelvio', ..., 5000, 21, 27],
#        [3, 1, 'alfa-romero Quadrifoglio', ..., 5000, 19, 26],
#        ...,
#        [203, -1, 'volvo 244dl', ..., 5500, 18, 23],
#        [204, -1, 'volvo 246', ..., 4800, 26, 27],
#        [205, -1, 'volvo 264gl', ..., 5400, 19, 25]], dtype=object)

# %%
y=data.iloc[:,-1].values

# %%
y
# Out:
# array([13495.   , 16500.   , 16500.   , 13950.   , 17450.   , 15250.   ,
#        17710.   , 18920.   , 23875.   , 17859.167, 16430.   , 16925.   ,
#        20970.   , 21105.   , 24565.   , 30760.   , 41315.   , 36880.   ,
#         5151.   ,  6295.   ,  6575.   ,  5572.   ,  6377.   ,  7957.   ,
#         6229.   ,  6692.   ,  7609.   ,  8558.   ,  8921.   , 12964.   ,
#         6479.   ,  6855.   ,  5399.   ,  6529.   ,  7129.   ,  7295.   ,
#         7295.   ,  7895.   ,  9095.   ,  8845.   , 10295.   , 12945.   ,
#        10345.   ,  6785.   ,  8916.5  ,  8916.5  , 11048.   , 32250.   ,
#        35550.   , 36000.   ,  5195.   ,  6095.   ,  6795.   ,  6695.   ,
#         7395.   , 10945.   , 11845.   , 13645.   , 15645.   ,  8845.   ,
#         8495.   , 10595.   , 10245.   , 10795.   , 11245.   , 18280.   ,
#        18344.   , 25552.   , 28248.   , 28176.   , 31600.   , 34184.   ,
#        35056.   , 40960.   , 45400.   , 16503.   ,  5389.   ,  6189.   ,
# ...

# %%
x=x.reshape(-1,1)
print(x)
# Out:
# [[1]
#  [3]
#  ['alfa-romero giulia']
#  ...
#  [5400]
#  [19]
#  [25]]

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.set_theme()
sns.countplot(x='CarName',data=data,palette="ch:start=.2,rot=-.3")
plt.xlabel("CarName",fontweight='bold',size=13)
plt.ylabel("count",fontweight='bold',size=13)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.set_theme()
sns.lineplot(x='car_ID',y='carbody',data=data)
plt.xlabel("car_ID",fontweight='bold',size=13)
plt.ylabel("carbody",fontweight='bold',size=13)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.set_theme()
sns.lineplot(x='car_ID',y='carbody',data=data)
plt.xlabel("car_ID",fontweight='bold',size=13)
plt.ylabel("stroke",fontweight='bold',size=13)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.set_theme()
sns.lineplot(x='car_ID',y='carbody',data=data)
plt.xlabel("car_ID",fontweight='bold',size=10)
plt.ylabel("price",fontweight='bold',size=10)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.catplot(x='CarName',y='carbody',data=data,palette="crest")
plt.show()
# Out:
# <ipython-input-29-26a785cd24e7>:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x='CarName',y='carbody',data=data,palette="crest")

# %%
plt.figure(figsize=(10,5))
sns.catplot(x='CarName',y='price',data=data,palette="crest")
plt.show()
# Out:
# <ipython-input-30-b0a4c95f1b67>:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x='CarName',y='price',data=data,palette="crest")

# %%
plt.figure(figsize=(10,5))
sns.catplot(x='CarName',y='stroke',data=data,palette="crest")
plt.show()
# Out:
# <ipython-input-31-c4074942c1be>:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x='CarName',y='stroke',data=data,palette="crest")

# %%
fig,axes=plt.subplots(2,2,figsize=(18,10))
fig.suptitle('Price Range vs all numerical factor')
sns.scatterplot(ax=axes[0,0],data=data,x='CarName',y='carbody')
sns.scatterplot(ax=axes[0,1],data=data,x='CarName',y='stroke')
sns.scatterplot(ax=axes[1,0],data=data,x='CarName',y='price')
plt.show()

# %%
def LABEL_ENCODING(c1):
  from sklearn import preprocessing
  label_encoder=preprocessing.LabelEncoder()
  data[c1]=label_encoder.fit_transform(data[c1])
  data[c1].unique()
LABEL_ENCODING("car_ID")
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         0          3        alfa-romero giulia      gas        std
# 1         1          3       alfa-romero stelvio      gas        std
# 2         2          1  alfa-romero Quadrifoglio      gas        std
# 3         3          2               audi 100 ls      gas        std
# 4         4          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     200         -1           volvo 145e (sw)      gas        std
# 201     201         -1               volvo 144ea      gas      turbo
# 202     202         -1               volvo 244dl      gas        std
# 203     203         -1                 volvo 246   diesel      turbo
# 204     204         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
x=data.drop('car_ID',axis=1)
y=data['car_ID']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 163          1   toyota corolla liftback      gas        std        two
# 61           1          mazda glc custom      gas        std        two
# 75           1            mercury cougar      gas      turbo        two
# 106          1            nissan clipper      gas        std        two
# 63           0          mazda glc deluxe   diesel        std       four
# ..         ...                       ...      ...        ...        ...
# 67          -1  buick electra 225 custom   diesel      turbo       four
# 192          0  volkswagen rabbit custom   diesel      turbo       four
# 117          0             peugeot 604sl      gas      turbo       four
# 47           0                 jaguar xj      gas        std       four
# 172          2           toyota cressida      gas        std        two
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
x_test
# Out:
#      symboling                          CarName fueltype aspiration  \
# 52           1                  mazda rx2 coupe      gas        std
# 181         -1                   toyouta tercel      gas        std
# 5            2                         audi fox      gas        std
# 18           2                 chevrolet impala      gas        std
# 188          2                volkswagen dasher      gas        std
# 170          2                    toyota tercel      gas        std
# 76           2                mitsubishi mirage      gas        std
# 154          0         toyota corolla 1600 (sw)      gas        std
# 104          3                     nissan teana      gas        std
# 33           1                honda accord cvcc      gas        std
# 12           0                           bmw x1      gas        std
# 129          1                  porsche cayenne      gas        std
# 55           3                        mazda 626      gas        std
# ...

# %%
y_train
# Out:
# 163    163
# 61      61
# 75      75
# 106    106
# 63      63
#       ...
# 67      67
# 192    192
# 117    117
# 47      47
# 172    172
# Name: car_ID, Length: 153, dtype: int64

# %%
y_test
# Out:
# 52      52
# 181    181
# 5        5
# 18      18
# 188    188
# 170    170
# 76      76
# 154    154
# 104    104
# 33      33
# 12      12
# 129    129
# 55      55
# 66      66
# 45      45
# 169    169
# 130    130
# 7        7
# 37      37
# 152    152
# 80      80
# 111    111
# 131    131
# 171    171
# 179    179
# 138    138
# 156    156
# 113    113
# 161    161
# 89      89
# 183    183
# 193    193
# 125    125
# 173    173
# 92      92
# 16      16
# 189    189
# 136    136
# 22      22
# 74      74
# 44      44
# 4        4
# 71      71
# 134    134
# 145    145
# 122    122
# 26      26
# 83      83
# 149    149
# 186    186
# 8        8
# 90      90
# Name: car_ID, dtype: int64

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (153, 25)
# (52, 25)
# (153,)
# (52,)
